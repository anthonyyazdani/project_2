# %% [markdown]
# - Glove 200d:
#
#     - Self made Data:
#         - Importing **self made** data
#         - Models:
#             - LTSM
#             - CNN
#             - (CNN + LSTM)
#
#     - Trivial Data:
#         - Importing **trivial** data
#         - Models:
#             - LTSM
#             - CNN
#             - (CNN + LSTM)

# %% [markdown]
# --------------------------------------------------------------
# Advices:
# - See **Classical_ML_glove_200d.ipynb** to mimic the procedure
# - try to use existing functions instead of creating new ones, like **load_data()** or **create_csv_submission()** for example
# --------------------------------------------------------------

# %% [markdown]
# # Glove 200d

# %% [markdown]
# ## Self made Data

# %% [markdown]
# ## Models

# %% [markdown]
# ###### LSTM

# %% [markdown]
# ###### CNN

# %% [markdown]
# ###### (CNN + LSTM)

# %% [markdown]
# # Trivial Data

# %% [markdown]
# ## Models

# %% [markdown]
# ###### LSTM

# %% [markdown]
# ###### CNN

# %% [markdown]
# ###### (CNN + LSTM)

# %% [markdown]
# # Saving results

# %% [markdown]
# ###### Self made data

# %% [markdown]
# - See **Classical_ML_glove_200d.ipynb** to mimic the saving procedure but changing to the correct folder

# %% [markdown]
# ###### Trivial data

# %% [markdown]
# - See **Classical_ML_glove_200d.ipynb** to mimic the saving procedure but changing to the correct folder
